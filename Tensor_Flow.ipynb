# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import Adam
from keras.models import Sequential

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
(x_train,x_test)=(x_train/255.0,x_test/255.0)

# %%
model=tf.keras.models.Sequential([
tf.keras.layers.Flatten(input_shape=(28,28)),
tf.keras.layers.Dense(512,activation='relu'),
tf.keras.layers.Dropout(0,2),
tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='SGD',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])

# %%
tf_callbacks=tf.keras.callbacks.TensorBoard(log_dir="logS/fit",histogram_freq=1)

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,callbacks=tf_callbacks)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 27s 13ms/step - loss: 0.6081 - accuracy: 0.8518 - val_loss: 0.3393 - val_accuracy: 0.9092
# Epoch 2/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3207 - accuracy: 0.9112 - val_loss: 0.2834 - val_accuracy: 0.9213
# Epoch 3/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2731 - accuracy: 0.9240 - val_loss: 0.2470 - val_accuracy: 0.9311
# Epoch 4/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2427 - accuracy: 0.9330 - val_loss: 0.2238 - val_accuracy: 0.9378
# Epoch 5/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2198 - accuracy: 0.9393 - val_loss: 0.2060 - val_accuracy: 0.9428
# Epoch 6/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2009 - accuracy: 0.9448 - val_loss: 0.1901 - val_accuracy: 0.9456
# Epoch 7/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.1850 - accuracy: 0.9489 - val_loss: 0.1773 - val_accuracy: 0.9496
# Epoch 8/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.1714 - accuracy: 0.9526 - val_loss: 0.1659 - val_accuracy: 0.9521
# Epoch 9/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.1597 - accuracy: 0.9560 - val_loss: 0.1568 - val_accuracy: 0.9552
# Epoch 10/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.1495 - accuracy: 0.9590 - val_loss: 0.1489 - val_accuracy: 0.9576

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir log/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 6028), started 10 days, 0:17:54 ago. (Use '!kill 6028' to kill it.)
#       <iframe id="tensorboard-frame-6fb9b0056be0de66" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6fb9b0056be0de66");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'],loc='upper left')
plt.show()
